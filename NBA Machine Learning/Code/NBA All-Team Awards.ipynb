# %%
from urllib2 import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
# url that we are scraping
url = "http://www.basketball-reference.com/awards/all_league.html"
html = urlopen(url)  # get the html
soup = BeautifulSoup(html, "lxml") # create our BS object

data_rows = soup.findAll('tr')[0:]  # skip the first header row
player_data = [[td.getText() for td in data_rows[i].findAll('td')]
            for i in range(len(data_rows))]

column_headers = ['Season', 'League', 'Team', 'C', 'F1', 'F2','G1','G2']
award_df = pd.DataFrame(player_data, columns=column_headers)

# %%
#Lets Clean the data: Remove the empty rows
award_df= award_df[award_df.Season.notnull()]

#Remove position and keep only the names in the C, F1, F2, G1, G2 columns
award_df['C']= award_df.C.apply(lambda x: x.split(' ')[0] + ' ' + x.split(' ')[1])
award_df['F1']= award_df.F1.apply(lambda x: x.split(' ')[0] + ' ' + x.split(' ')[1])
award_df['F2']= award_df.F2.apply(lambda x: x.split(' ')[0] + ' ' + x.split(' ')[1])
award_df['G1']= award_df.G1.apply(lambda x: x.split(' ')[0] + ' ' + x.split(' ')[1])
award_df['G2']= award_df.G2.apply(lambda x: x.split(' ')[0] + ' ' + x.split(' ')[1])

#Format Season column so that only the ending season is listed. e.g .2014-2015 => 2015
award_df['Season'] = award_df.Season.apply(lambda x: x.split('-')[0])
award_df['Season'] = award_df.Season.apply(lambda x: int(x)+1)

#Format Team column so that 1st, 2nd, 3rd becomes 1, 2, 3
award_df['Team'] = award_df.Team.apply(lambda x: x[0])

#keep only results from 1990 to now
award_df = award_df[award_df.Season > 1989]

#drop League column
award_df = award_df.drop(['League'], axis = 1)

# %%
#check types & make conversions
award_df['Season'] = award_df['Season'].astype(float)
award_df.dtypes
# Out:
# Season    float64
# Team       object
# C          object
# F1         object
# F2         object
# G1         object
# G2         object
# dtype: object

# %%
award_df = award_df.reset_index(drop=True)
award_df
# Out:
#     Season Team                  C                 F1                 F2  \
# 0     2015    1         Marc Gasol      Anthony Davis       LeBron James
# 1     2015    2          Pau Gasol   DeMarcus Cousins  LaMarcus Aldridge
# 2     2015    3     DeAndre Jordan         Tim Duncan      Blake Griffin
# 3     2014    1        Joakim Noah       LeBron James       Kevin Durant
# 4     2014    2      Dwight Howard      Blake Griffin         Kevin Love
# 5     2014    3       Al Jefferson  LaMarcus Aldridge        Paul George
# 6     2013    1         Tim Duncan       LeBron James       Kevin Durant
# 7     2013    2         Marc Gasol      Blake Griffin    Carmelo Anthony
# 8     2013    3      Dwight Howard          David Lee        Paul George
# 9     2012    1      Dwight Howard       LeBron James       Kevin Durant
# 10    2012    2       Andrew Bynum         Kevin Love      Blake Griffin
# 11    2012    3     Tyson Chandler    Carmelo Anthony      Dirk Nowitzki
# 12    2011    1      Dwight Howard       Kevin Durant       LeBron James
# 13    2011    2  Amar'e Stoudemire          Pau Gasol      Dirk Nowitzki
# 14    2011    3         Al Horford  LaMarcus Aldridge      Zach Randolph
# 15    2010    1      Dwight Howard       LeBron James       Kevin Durant
# 16    2010    2  Amar'e Stoudemire    Carmelo Anthony      Dirk Nowitzki
# 17    2010    3       Andrew Bogut         Tim Duncan          Pau Gasol
# 18    2009    1      Dwight Howard       LeBron James      Dirk Nowitzki
# 19    2009    2           Yao Ming         Tim Duncan        Paul Pierce
# 20    2009    3   Shaquille O'Neal    Carmelo Anthony          Pau Gasol
# 21    2008    1      Dwight Howard      Kevin Garnett       LeBron James
# 22    2008    2  Amar'e Stoudemire         Tim Duncan      Dirk Nowitzki
# 23    2008    3           Yao Ming      Carlos Boozer        Paul Pierce
# 24    2007    1  Amar'e Stoudemire         Tim Duncan      Dirk Nowitzki
# 25    2007    2           Yao Ming         Chris Bosh       LeBron James
# 26    2007    3      Dwight Howard      Kevin Garnett    Carmelo Anthony
# 27    2006    1   Shaquille O'Neal       LeBron James      Dirk Nowitzki
# 28    2006    2        Ben Wallace         Tim Duncan        Elton Brand
# 29    2006    3           Yao Ming       Shawn Marion    Carmelo Anthony
# ..     ...  ...                ...                ...                ...
# 48    1999    1    Alonzo Mourning        Karl Malone         Tim Duncan
# 49    1999    2   Shaquille O'Neal         Grant Hill       Chris Webber
# 50    1999    3    Hakeem Olajuwon    Antonio McDyess      Kevin Garnett
# 51    1998    1   Shaquille O'Neal        Karl Malone         Tim Duncan
# 52    1998    2     David Robinson         Grant Hill          Vin Baker
# 53    1998    3    Dikembe Mutombo     Scottie Pippen          Glen Rice
# 54    1997    1    Hakeem Olajuwon        Karl Malone         Grant Hill
# 55    1997    2      Patrick Ewing     Scottie Pippen          Glen Rice
# 56    1997    3   Shaquille O'Neal      Anthony Mason          Vin Baker
# 57    1996    1     David Robinson     Scottie Pippen        Karl Malone
# 58    1996    2    Hakeem Olajuwon         Grant Hill         Shawn Kemp
# 59    1996    3   Shaquille O'Neal    Charles Barkley       Juwan Howard
# 60    1995    1     David Robinson     Scottie Pippen        Karl Malone
# 61    1995    2   Shaquille O'Neal         Shawn Kemp    Charles Barkley
# 62    1995    3    Hakeem Olajuwon    Detlef Schrempf      Dennis Rodman
# 63    1994    1    Hakeem Olajuwon     Scottie Pippen        Karl Malone
# 64    1994    2     David Robinson    Charles Barkley         Shawn Kemp
# 65    1994    3   Shaquille O'Neal    Derrick Coleman  Dominique Wilkins
# 66    1993    1    Hakeem Olajuwon    Charles Barkley        Karl Malone
# 67    1993    2      Patrick Ewing  Dominique Wilkins      Larry Johnson
# 68    1993    3     David Robinson     Scottie Pippen    Derrick Coleman
# 69    1992    1     David Robinson       Chris Mullin        Karl Malone
# 70    1992    2      Patrick Ewing     Scottie Pippen    Charles Barkley
# 71    1992    3     Brad Daugherty      Dennis Rodman       Kevin Willis
# 72    1991    1     David Robinson        Karl Malone    Charles Barkley
# 73    1991    2      Patrick Ewing       Chris Mullin  Dominique Wilkins
# 74    1991    3    Hakeem Olajuwon       James Worthy       Bernard King
# 75    1990    1      Patrick Ewing    Charles Barkley        Karl Malone
# 76    1990    2    Hakeem Olajuwon         Larry Bird       Tom Chambers
# 77    1990    3     David Robinson       Chris Mullin       James Worthy
#
#                    G1                 G2
# 0        James Harden      Stephen Curry
# 1          Chris Paul  Russell Westbrook
# 2        Kyrie Irving      Klay Thompson
# 3        James Harden         Chris Paul
# 4       Stephen Curry        Tony Parker
# 5      Damian Lillard       Goran Dragic
# 6         Kobe Bryant         Chris Paul
# 7   Russell Westbrook        Tony Parker
# 8        James Harden        Dwyane Wade
# 9         Kobe Bryant         Chris Paul
# 10  Russell Westbrook        Tony Parker
# 11        Dwyane Wade        Rajon Rondo
# 12        Kobe Bryant       Derrick Rose
# 13        Dwyane Wade  Russell Westbrook
# 14      Manu Ginobili         Chris Paul
# 15        Kobe Bryant        Dwyane Wade
# 16         Steve Nash     Deron Williams
# 17        Brandon Roy        Joe Johnson
# 18        Dwyane Wade        Kobe Bryant
# 19         Chris Paul        Brandon Roy
# 20        Tony Parker   Chauncey Billups
# 21         Chris Paul        Kobe Bryant
# 22         Steve Nash     Deron Williams
# 23      Manu Ginobili      Tracy McGrady
# 24        Kobe Bryant         Steve Nash
# 25     Gilbert Arenas      Tracy McGrady
# 26        Dwyane Wade   Chauncey Billups
# 27         Steve Nash        Kobe Bryant
# 28        Dwyane Wade   Chauncey Billups
# 29     Gilbert Arenas      Allen Iverson
# ..                ...                ...
# 48      Allen Iverson         Jason Kidd
# 49       Tim Hardaway        Gary Payton
# 50        Kobe Bryant      John Stockton
# 51     Michael Jordan        Gary Payton
# 52     Rod Strickland       Tim Hardaway
# 53      Reggie Miller     Mitch Richmond
# 54     Michael Jordan       Tim Hardaway
# 55        Gary Payton     Mitch Richmond
# 56      John Stockton  Anfernee Hardaway
# 57  Anfernee Hardaway     Michael Jordan
# 58      John Stockton        Gary Payton
# 59      Reggie Miller     Mitch Richmond
# 60      John Stockton  Anfernee Hardaway
# 61        Gary Payton     Mitch Richmond
# 62      Reggie Miller      Clyde Drexler
# 63   Latrell Sprewell      John Stockton
# 64     Mitch Richmond      Kevin Johnson
# 65        Gary Payton         Mark Price
# 66     Michael Jordan         Mark Price
# 67      John Stockton         Joe Dumars
# 68       Tim Hardaway    Drazen Petrovic
# 69     Michael Jordan      Clyde Drexler
# 70      John Stockton       Tim Hardaway
# 71         Mark Price      Kevin Johnson
# 72     Michael Jordan      Magic Johnson
# 73      Kevin Johnson      Clyde Drexler
# 74         Joe Dumars      John Stockton
# 75      Magic Johnson     Michael Jordan
# 76      Kevin Johnson      John Stockton
# 77      Clyde Drexler         Joe Dumars
#
# [78 rows x 7 columns]

# %%
award_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 0 to 77
# Data columns (total 7 columns):
# Season    78 non-null float64
# Team      78 non-null object
# C         78 non-null object
# F1        78 non-null object
# F2        78 non-null object
# G1        78 non-null object
# G2        78 non-null object
# dtypes: float64(1), object(6)
# memory usage: 4.9+ KB

# %%
#Convert this to csv
award_df.to_csv("../Data/Award_winners_1990_to_2015.csv")

# %%
#separate dataframe by position, then reconstruct all 5 positions into 1 dataframe. Prob better way to do this
#Centers
Center = award_df.iloc[:,[0,1,2]]
Center.rename(columns={'C': 'Winner'}, inplace=True)
#Power Forwards
Forward1 = award_df.iloc[:,[0,1,3]]
Forward1.rename(columns={'F1': 'Winner'}, inplace =True)
#Small Forwards
Forward2 = award_df.iloc[:,[0,1,4]]
Forward2.rename(columns={'F2': 'Winner'}, inplace =True)
#Shooting Guards
Guard1 = award_df.iloc[:,[0,1,5]]
Guard1.rename(columns={'G1': 'Winner'}, inplace =True)
#Point Guards
Guard2 = award_df.iloc[:,[0,1,6]]
Guard2.rename(columns={'G2': 'Winner'}, inplace =True)

# %%
#combine dataframe into one
df_new = pd.concat([Center, Forward1, Forward2, Guard1, Guard2])
df_new.rename(columns={'Season': 'Year'}, inplace = True)
df_new = df_new.reset_index(drop=True)

df_new.head(10)
# Out:
#    Year Team          Winner
# 0  2015    1      Marc Gasol
# 1  2015    2       Pau Gasol
# 2  2015    3  DeAndre Jordan
# 3  2014    1     Joakim Noah
# 4  2014    2   Dwight Howard
# 5  2014    3    Al Jefferson
# 6  2013    1      Tim Duncan
# 7  2013    2      Marc Gasol
# 8  2013    3   Dwight Howard
# 9  2012    1   Dwight Howard

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390 entries, 0 to 389
# Data columns (total 3 columns):
# Year      390 non-null float64
# Team      390 non-null object
# Winner    390 non-null object
# dtypes: float64(1), object(2)
# memory usage: 12.2+ KB

# %%
#Convert this to csv
df_new.to_csv("../Data/Transformed_Award_winners_1990_to_2015.csv")
